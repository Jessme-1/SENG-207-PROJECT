# %%
import pandas as pd 
import seaborn as sn 
from matplotlib import pyplot as plt
import numpy as np

# %%
dataset=pd.read_csv('data.csv')

# %%
dataset
# Out:
#         ID  fixed_acidity  volatile acidity  citric_acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  freesulfurdioxide  totalsulfurdioxide  density        pH  \
# ...

# %% [markdown]
#  ## DATA INFO

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1600 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1600 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1598 non-null   float64
#  6   free sulfur dioxide   1600 non-null   float64
#  7   total sulfur dioxide  1600 non-null   float64
#  8   density               1600 non-null   float64
#  9   pH                    1600 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1600 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %% [markdown]
# ## RENAME OF SPECIFIC COLUMNS

# %%
dataset.rename(columns={'fixed acidity':'fixed_acidity', 
                     'citric acid':'citric_acid', 
                     'free sulfur dioxide':'freesulfurdioxide', 
                     'total sulfur dioxide':'totalsulfurdioxide'})
# Out:
#         ID  fixed_acidity  volatile acidity  citric_acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  freesulfurdioxide  totalsulfurdioxide  density    pH  \
# ...

# %%
dataset=dataset.rename(columns={'fixed acidity':'fixed_acidity', 
                     'citric acid':'citric_acid', 
                     'free sulfur dioxide':'freesulfurdioxide', 
                     'total sulfur dioxide':'totalsulfurdioxide'})

# %% [markdown]
# ## RENAMED DATA

# %%
dataset
# Out:
#         ID  fixed_acidity  volatile acidity  citric_acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  freesulfurdioxide  totalsulfurdioxide  density    pH  \
# ...

# %%
dataset.dropna()
# Out:
#         ID  fixed_acidity  volatile acidity  citric_acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# 5        6            7.4             0.660         0.00             1.8
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  freesulfurdioxide  totalsulfurdioxide  density    pH  \
# ...

# %%
dataset.dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1591 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  1591 non-null   int64
#  1   fixed_acidity       1591 non-null   float64
#  2   volatile acidity    1591 non-null   float64
#  3   citric_acid         1591 non-null   float64
#  4   residual sugar      1591 non-null   float64
#  5   chlorides           1591 non-null   float64
#  6   freesulfurdioxide   1591 non-null   float64
#  7   totalsulfurdioxide  1591 non-null   float64
#  8   density             1591 non-null   float64
#  9   pH                  1591 non-null   float64
#  10  sulphates           1591 non-null   float64
#  11  alcohol             1591 non-null   float64
#  12  quality             1591 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 174.0 KB

# %%
dataset.head(50)
# Out:
#     ID  fixed_acidity  volatile acidity  citric_acid  residual sugar  \
# 0    1            7.4             0.700         0.00             1.9
# 1    2            7.8             0.880         0.00             2.6
# 2    3            7.8             0.760         0.04             2.3
# 3    4           11.2             0.280         0.56             1.9
# 4    5            7.4             0.700         0.00             1.9
# 5    6            7.4             0.660         0.00             1.8
# 6    7            7.9             0.600         0.06             1.6
# 7    8            7.3             0.650         0.00             1.2
# 8    9            7.8             0.580         0.02             2.0
# 9   10            7.5             0.500         0.36             6.1
# 10  11            6.7             0.580         0.08             1.8
# 11  12            7.5             0.500         0.36             6.1
# 12  13            5.6             0.615         0.00             1.6
# ...

# %% [markdown]
# The dataset.head(50) shows the first 50 rows which was truncated at first

# %%
dataset.describe()
# Out:
#                 ID  fixed_acidity  volatile acidity  citric_acid  \
# count  1601.000000    1600.000000       1601.000000  1600.000000
# mean    801.000000       8.319875          0.527742     0.271175
# std     462.313206       1.740039          0.178981     0.194745
# min       1.000000       4.600000          0.120000     0.000000
# 25%     401.000000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1201.000000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual sugar    chlorides  freesulfurdioxide  totalsulfurdioxide  \
# count     1601.000000  1598.000000        1600.000000         1600.000000
# mean         2.538445     0.087487          15.886875           46.520000
# std          1.409138     0.047076          10.458487           32.977723
# min          0.900000     0.012000           1.000000            6.000000
# ...

# %% [markdown]
# ## MEAN OF SPECIFIC COLUMNS

# %%
meanFA=dataset.fixed_acidity.mean()
meanCc=dataset.citric_acid.mean()
meanCh=dataset.chlorides.mean()
meanFso=dataset.freesulfurdioxide.mean()
meanTso=dataset.totalsulfurdioxide.mean()
meanD=dataset.density.mean()
meanpH=dataset.pH.mean()
meanquality=dataset.quality.mean()

# %%
print(meanFA)
print(meanCc)
print(meanCh)
print(meanFso)
print(meanTso)
print(meanD)
print(meanpH)
print(meanquality)
# Out:
# 8.319875000000001
# 0.271175
# 0.0874874843554443
# 15.886875
# 46.52
# 0.9967456437500002
# 3.3111062500000004
# 5.63625

# %% [markdown]
# ## FILLING IN NULL DATAS WITH THEIR MEAN

# %%
dataset['fixeda_cidity'] = dataset['fixed_acidity'].fillna(meanFA)
dataset['citri_cacid'] = dataset['citric_acid'].fillna(meanCc)
dataset['chlorides'] = dataset['chlorides'].fillna(meanCh)
dataset['freesulfurdioxide'] = dataset['freesulfurdioxide'].fillna(meanFso)
dataset['totalsulfurdioxide'] = dataset['totalsulfurdioxide'].fillna(meanTso)
dataset['density'] = dataset['density'].fillna(meanD)
dataset['pH'] = dataset['pH'].fillna(meanpH)
dataset['quality'] = dataset['quality'].fillna(meanquality)

# %% [markdown]
# ## FILLED IN DATA(NO NULL VALUES)

# %%
dataset
# Out:
#         ID  fixed_acidity  volatile acidity  citric_acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  freesulfurdioxide  totalsulfurdioxide  density        pH  \
# ...

# %% [markdown]
# ## PIE CHART

# %%
meanOf_dataset=np.array([8.319875,15.886875,46.52,3.31110625,5.63625])
myLabels=['fixed_acidity','freeSO','totalSO','pH','quality',]
explode=(0,0.2,0,0.2,0,)

plt.figure(figsize=(6,9))
plt.title('Mean Of specific columns', fontsize=8, fontweight='bold')
plt.style.use('ggplot')
plt.pie(meanOf_dataset,labels=myLabels,explode=explode,startangle=0,autopct='%.1f%%')
plt.legend(loc='upper left', fontsize=6)
plt.show()

# %% [markdown]
# The pie chart describes the columns according to their averaged values, wwhich indicates the quantity of each columns in the beverage. The quality is low for the averaged value.

# %%
dataset.corr()
# Out:
#                           ID  fixed_acidity  volatile acidity  citric_acid  \
# ID                  1.000000      -0.268147         -0.009544    -0.153429
# fixed_acidity      -0.268147       1.000000         -0.255570     0.671061
# volatile acidity   -0.009544      -0.255570          1.000000    -0.552917
# citric_acid        -0.153429       0.671061         -0.552917     1.000000
# residual sugar     -0.031589       0.114601          0.001877     0.143518
# chlorides          -0.119131       0.093472          0.060748     0.203981
# freesulfurdioxide   0.091145      -0.153045         -0.010591    -0.061260
# totalsulfurdioxide -0.113809      -0.113325          0.076247     0.036019
# density            -0.368725       0.667893          0.022753     0.364104
# pH                  0.135082      -0.682625          0.235182    -0.542779
# sulphates          -0.124243       0.182303         -0.261364     0.312895
# ...

# %% [markdown]
# ## CORELATING MAX QUALITY AND pH

# %%
x= dataset.quality < dataset.pH

x.value_counts()
# Out:
# False    1591
# True       10
# dtype: int64

# %%
correLation=([8.000,4.000])
theLabels=('quality','pH')

# %%
plt.figure(figsize=(5,7))
plt.title('Correlation Between Fixedacidity And pH', fontsize=9, fontweight='bold')
plt.style.use('ggplot')
plt.pie(correLation,labels=theLabels,autopct='%.1f%%')
plt.legend(loc='upper left', fontsize=7)
plt.show()
